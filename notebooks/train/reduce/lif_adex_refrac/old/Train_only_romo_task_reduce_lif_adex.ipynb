# %% [markdown]
# # Two task network
#
# ## Network has some inputs
#
# 1. The fixation.
# 1. The first context mod.
# 1. The second ontext mod.
#
# ## Network has five outputs
# 1. The fixation.
# 1. The first output.
# 1. The second output
#
#
#
#
# <div>
# <img src="./images/Sheme.png" width="300"/>
# </div>
#
# > Learning rule: superspike
#
# > Neuron type: Lif + refrac
#
# > Task: romo

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt  # for analys
from cgtasknet.net.lifadexrefrac import SNNlifadexrefrac
from cgtasknet.tasks.reduce import RomoTask, DefaultParams
from norse.torch.functional.lif_adex_refrac import LIFAdExRefracParameters
from norse.torch.functional.lif_adex import LIFAdExParameters

# from norse.torch import LIF

# %% [markdown]
# ## Step -1: Create dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device('cpu')
print(f'Device: {("gpu (cuda)" if device.type=="cuda" else "cpu")}')
# Out:
# Device: gpu (cuda)

# %%
batch_size = 50
number_of_tasks = 2
task_parameters = DefaultParams("RomoTask").generate_params()
task_parameters["delay"] = 0.1
task_parameters["trial_time"] = 0.1
Task = RomoTask(params=task_parameters, batch_size=batch_size)
Task_test = RomoTask(params=task_parameters, batch_size=1)
print("Task params:")
for key in task_parameters:
    if key != "values":
        print(
            f"{key}".center(10, "."),
            f'value: {int((task_parameters[key] / task_parameters["dt"]))}ms',
        )
# Out:
# Task params:
# ....dt.... value: 1ms
# ..delay... value: 100ms
# trial_time value: 100ms

# %% [markdown]
# ## Step 1.1: Create model

# %%
feature_size, output_size = Task.feature_and_act_size
hidden_size = 250

neuron_parameters = LIFAdExRefracParameters(
    LIFAdExParameters(
        v_th=torch.as_tensor(0.65).to(device),
        tau_ada_inv=torch.as_tensor(1).to(device),
    ),
    rho_reset=torch.as_tensor(0.5).to(device),
)
model = SNNlifadexrefrac(
    feature_size,
    hidden_size,
    output_size,
    neuron_parameters=neuron_parameters,
    tau_filter_inv=500,
).to(device)

# %% [markdown]
# ## Step 1.2: Save pre-learning weights

# %%
weights_pre_l = []
with torch.no_grad():
    for name, param in model.named_parameters():
        if param.requires_grad:
            weights_pre_l.append((param).cpu().numpy())

# %% [markdown]
# ## Step 2: loss and creterion

# %%
learning_rate = 1e-3


class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))


criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# %matplotlib widget
plt.ion

fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Step 3: Train loop

# %%
from cgtasknet.net.states import LIFAdExRefracInitState

init_state = LIFAdExRefracInitState(batch_size, hidden_size, device=device)

ax.set_title("lif adex refrac")
inputs, target_outputs = Task.dataset(number_of_tasks)
running_loss = 0
fig.canvas.draw()
fig.canvas.flush_events()
for i in range(4000):
    dmparams1 = DefaultParams("RomoTask").generate_params()

    dmparams1["delay"] = np.random.uniform(0.01, 0.2)
    dmparams1["trial_time"] = np.random.uniform(0.1, 0.25)
    Task.params = dmparams1
    inputs, target_outputs = Task.dataset(number_of_tasks, delay_between=200)
    inputs += np.random.normal(0, 0.01, size=(inputs.shape))
    inputs = torch.from_numpy(inputs).type(torch.float).to(device)
    target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs, states = model(inputs, state=init_state.random_state())

    loss = criterion(outputs, target_outputs)
    loss.backward()
    optimizer.step()

    # print statistics
    running_loss += loss.item()
    if i % 10 == 9:
        print("epoch: {:d} loss: {:0.5f}".format(i + 1, running_loss / 10))
        running_loss = 0.0
        with torch.no_grad():
            Task_test.params = dmparams1
            inputs, target_outputs = Task_test.dataset(
                number_of_tasks, delay_between=200
            )

            inputs = torch.from_numpy(inputs).type(torch.float).to(device)
            target_outputs = (
                torch.from_numpy(target_outputs).type(torch.float).to(device)
            )
            outputs, states = model(inputs)
            loss = criterion(outputs, target_outputs)
            torch.save(
                model.state_dict(),
                "Only_romo_lif_adex_refrac_net_random_two_trials_250",
            )
            print("test loss: {:0.5f}".format(loss.item()))
        for_plot = outputs.detach().cpu().numpy()[:, 0, :]
        ax.clear()
        ax.plot(for_plot[:, 1], c="r")
        ax.plot(for_plot[:, 2], c="b")
        ax.plot(target_outputs.detach().cpu().numpy()[:, 0, 1], c="r")
        ax.plot(target_outputs.detach().cpu().numpy()[:, 0, 2], c="b")

    fig.canvas.draw()
    fig.canvas.flush_events()
print("Finished Training")
# Out:
# epoch: 10 loss: 0.27805
# test loss: 0.27489
# epoch: 20 loss: 0.24052
# test loss: 0.19130
# epoch: 30 loss: 0.15889
# test loss: 0.11896
# epoch: 40 loss: 0.09215
# test loss: 0.06226
# epoch: 50 loss: 0.06355
# test loss: 0.04545
# epoch: 60 loss: 0.05214
# test loss: 0.04552
# epoch: 70 loss: 0.04902
# test loss: 0.05177
# epoch: 80 loss: 0.04281
# test loss: 0.04501
# epoch: 90 loss: 0.04519
# test loss: 0.04417
# epoch: 100 loss: 0.04327
# test loss: 0.04420
# epoch: 110 loss: 0.03944
# test loss: 0.03450
# epoch: 120 loss: 0.04169
# test loss: 0.04882
# epoch: 130 loss: 0.03678
# test loss: 0.03603
# epoch: 140 loss: 0.03600
# test loss: 0.02955
# epoch: 150 loss: 0.03644
# test loss: 0.02623
# epoch: 160 loss: 0.03496
# test loss: 0.03745
# epoch: 170 loss: 0.03408
# test loss: 0.03212
# epoch: 180 loss: 0.03274
# test loss: 0.02994
# epoch: 190 loss: 0.03899
# test loss: 0.03631
# epoch: 200 loss: 0.03156
# test loss: 0.03721
# epoch: 210 loss: 0.03190
# test loss: 0.02272
# epoch: 220 loss: 0.03599
# test loss: 0.02735
# epoch: 230 loss: 0.03246
# test loss: 0.02801
# epoch: 240 loss: 0.03872
# test loss: 0.02295
# epoch: 250 loss: 0.03166
# test loss: 0.02179
# epoch: 260 loss: 0.03241
# test loss: 0.02963
# epoch: 270 loss: 0.03378
# test loss: 0.01929
# epoch: 280 loss: 0.03354
# test loss: 0.03679
# epoch: 290 loss: 0.03173
# test loss: 0.03223
# epoch: 300 loss: 0.03335
# test loss: 0.02898
# epoch: 310 loss: 0.03461
# test loss: 0.02575
# epoch: 320 loss: 0.03072
# test loss: 0.02358
# epoch: 330 loss: 0.02554
# test loss: 0.04025
# epoch: 340 loss: 0.03274
# test loss: 0.02669
# epoch: 350 loss: 0.03140
# test loss: 0.04115
# epoch: 360 loss: 0.02798
# test loss: 0.02806
# epoch: 370 loss: 0.02909
# test loss: 0.03079
# epoch: 380 loss: 0.03374
# test loss: 0.04187
# test loss: 0.00619
# epoch: 3640 loss: 0.01274
# test loss: 0.00732
# epoch: 3650 loss: 0.01534
# test loss: 0.00852
# epoch: 3660 loss: 0.01424
# test loss: 0.00962
# epoch: 3670 loss: 0.01106
# test loss: 0.01351
# epoch: 3680 loss: 0.01303
# test loss: 0.00839
# epoch: 3690 loss: 0.01249
# test loss: 0.03194
# epoch: 3700 loss: 0.01515
# test loss: 0.01295
# epoch: 3710 loss: 0.01179
# test loss: 0.00965
# epoch: 3720 loss: 0.01273
# test loss: 0.01113
# epoch: 3730 loss: 0.01317
# test loss: 0.01240
# epoch: 3740 loss: 0.01304
# test loss: 0.00869
# epoch: 3750 loss: 0.01085
# test loss: 0.00688
# epoch: 3760 loss: 0.01132
# test loss: 0.00915
# epoch: 3770 loss: 0.01147
# test loss: 0.01517
# epoch: 3780 loss: 0.01076
# test loss: 0.00766
# epoch: 3790 loss: 0.01228
# test loss: 0.01925
# epoch: 3800 loss: 0.01163
# test loss: 0.00872
# epoch: 3810 loss: 0.01183
# test loss: 0.00868
# epoch: 3820 loss: 0.01102
# test loss: 0.00860
# epoch: 3830 loss: 0.01109
# test loss: 0.01893
# epoch: 3840 loss: 0.01276
# test loss: 0.01813
# epoch: 3850 loss: 0.01157
# test loss: 0.00882
# epoch: 3860 loss: 0.01162
# test loss: 0.00794
# epoch: 3870 loss: 0.01577
# test loss: 0.01266
# epoch: 3880 loss: 0.01390
# test loss: 0.01329
# epoch: 3890 loss: 0.01274
# test loss: 0.00692
# epoch: 3900 loss: 0.01342
# test loss: 0.01333
# epoch: 3910 loss: 0.01347
# test loss: 0.01290
# epoch: 3920 loss: 0.01330
# test loss: 0.01381
# epoch: 3930 loss: 0.01173
# test loss: 0.00851
# epoch: 3940 loss: 0.01044
# test loss: 0.00746
# epoch: 3950 loss: 0.01257
# test loss: 0.01210
# epoch: 3960 loss: 0.01200
# test loss: 0.03365
# epoch: 3970 loss: 0.01196
# test loss: 0.00710
# epoch: 3980 loss: 0.01119
# test loss: 0.00617
# epoch: 3990 loss: 0.01148
# test loss: 0.00679
# epoch: 4000 loss: 0.01202
# test loss: 0.00977
# Finished Training

# %%
from cgtasknet.instruments.instrument_accuracy_network import correct_answer
from tqdm import tqdm

result = 0
for i in tqdm(range(500)):
    dmparams1["delay"] = np.random.uniform(0.01, 0.2)
    dmparams1["trial_time"] = np.random.uniform(0.1, 0.25)
    Task = RomoTask(dmparams1, mode="random", batch_size=batch_size)

    inputs, target_outputs = Task.dataset(1, delay_between=200)
    # inputs = inputs * 2 - 1
    inputs += np.random.normal(0, 0.01, size=(inputs.shape))
    inputs = torch.from_numpy(inputs).type(torch.float).to(device)
    target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
    outputs = model(inputs)[0]
    answers = correct_answer(
        outputs[:, :, 1:], target_outputs[:, :, 1:], target_outputs[:, :, 0]
    )
    result += torch.sum(answers).item()
result / batch_size / 500 * 100
# Out:
# 100%|██████████| 500/500 [08:24<00:00,  1.01s/it]
# 94.136

# %%
torch.save(model.state_dict(), "Only_romo_lif_adex_refrac_net_random_two_trials_250")

# %%
if False:
    model.load_state_dict(torch.load("Only_dm_lif_net"))

# %%
dmparamsv = dmparams1
Taskplot = RomoTask(params=dmparamsv, batch_size=1, delay_beetween=100)
inputs, target_outputs = Taskplot.dataset(10)
inputs += np.random.normal(0, 0.01, size=(inputs.shape))
inputs = torch.from_numpy(inputs).type(torch.float).to(device)
target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
outputs, states = model(inputs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13604/1588404852.py in <module>
#       1 dmparamsv = dmparams1
# ----> 2 Taskplot = RomoTask(params=dmparamsv, batch_size=1, delay_beetween=100)
#       3 inputs, target_outputs = Taskplot.dataset(10)
#       4 inputs += np.random.normal(0, 0.01, size=(inputs.shape))
#       5 inputs = torch.from_numpy(inputs).type(torch.float).to(device)
#
# TypeError: __init__() got an unexpected keyword argument 'delay_beetween'

# %%
# %matplotlib inline
for i in range(inputs.shape[2]):
    plt.plot(inputs[:, 0, i].detach().cpu().numpy(), label=rf"$u_{i + 1}$")
    plt.legend()
    plt.show()
    plt.close()
for i in range(outputs.shape[2]):
    plt.plot(outputs[:, 0, i].detach().cpu().numpy(), label=rf"$u_{i + 1}$")
    plt.plot(
        target_outputs[:, 0, i].detach().cpu().numpy(), label=rf"$u^{{target}}_{i + 1}$"
    )
    plt.legend()
    plt.show()
    plt.close()

plt.plot(
    outputs[:, 0, -2].detach().cpu().numpy() - outputs[:, 0, -1].detach().cpu().numpy(),
    label=rf"$u_2 - u_3$",
)
plt.plot(target_outputs[:, 0, -2].detach().cpu().numpy(), label=rf"$u^{{target}}_{2}$")
plt.plot(target_outputs[:, 0, -1].detach().cpu().numpy(), label=rf"$u^{{target}}_{3}$")
plt.legend()
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15188/3921085042.py in <module>
#       5     plt.show()
#       6     plt.close()
# ----> 7 for i in range(outputs.shape[2]):
#       8     plt.plot(outputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")
#       9     plt.plot(
#
# NameError: name 'outputs' is not defined

# %%
# %matplotlib inline
for i in range(inputs.shape[2]):
    plt.plot(inputs[:, 0, i].detach().cpu().numpy(), label=rf"$u_{i + 1}$")

plt.legend()
plt.show()
plt.close()
plt.plot(target_outputs[:, 0, 1].detach().cpu().numpy(), label=rf"$y_{2}$")
plt.plot(target_outputs[:, 0, 2].detach().cpu().numpy(), label=rf"$y_{3}$")

# %%
weights_post_l = []
with torch.no_grad():
    for name, param in model.named_parameters():
        if param.requires_grad:
            weights_post_l.append((param).cpu().numpy())

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow((weights_pre_l[i]), aspect="auto", cmap="jet")
    plt.colorbar()
    plt.show()

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow(
        (weights_post_l[i]),
        aspect="auto",
        cmap="jet",
    )
    plt.colorbar()
    plt.show()

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow(
        (weights_post_l[i] - weights_pre_l[i]),
        aspect="auto",
        cmap="jet",
        vmin=-0.2,
        vmax=0.4,
    )
    plt.colorbar()
    plt.show()
