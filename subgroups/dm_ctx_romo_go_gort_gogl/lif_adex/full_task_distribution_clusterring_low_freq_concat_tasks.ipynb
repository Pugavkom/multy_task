# %%
import time
from typing import Iterable

import np as np
import torch
from cgtasknet.instruments.instrument_subgroups import SubgroupFinder
from cgtasknet.tasks.reduce import ReduceTaskCognitive


class EveryTaskSubgroups:
    device = torch.device("cpu")

    def __init__(
        self, model: torch.nn.Module, tasks: Iterable[ReduceTaskCognitive]
    ) -> None:
        self._tasks = tasks
        self._model = model
        self._subgroups_finder = None

    def run(self, number_of_trials: int, dt: float = 1e-3):
        self._subgroups_finder = []
        number_of_trials = int(number_of_trials)
        dt = float(dt)
        print("*" * 20, "Start")
        for current_task in self._tasks:
            t0 = time.perf_counter()
            self._subgroups_finder.append(SubgroupFinder(dt))
            for i in range(number_of_trials):
                status = False
                while not status:
                    inputs, t_outputs, s, out = self._run_trial(current_task)
                    status = self._subgroups_finder[-1].compute_average_freq(
                        [s.to(torch.device("cpu"))],
                        [inputs[:, 0, 0].to(torch.device("cpu"))],
                        [out.to(torch.device("cpu"))],
                        [t_outputs.to(torch.device("cpu"))],
                    )
            print(
                f"Complete task: {current_task.task_number}, time: {time.perf_counter() - t0}s"
            )

    def _run_trial(self, task: ReduceTaskCognitive):
        inputs, t_outputs = task.dataset()
        inputs = torch.from_numpy(inputs).type(torch.float).to(self.device)
        t_outputs = torch.from_numpy(t_outputs).type(torch.float).to(self.device)
        out, _, s = self._model(inputs)
        s = torch.stack(s).detach()
        s = s.reshape((s.shape[0], s.shape[2]))
        return inputs, t_outputs, s, out

    def get_frequencies(self):
        fixation = []
        answer = []
        for subgoup_finder in self._subgroups_finder:
            t_fixation, t_answer = subgoup_finder.get_average_freq()
            fixation.append(t_fixation)
            answer.append(t_answer)
        return fixation, answer

# %%
import torch
from cgtasknet.tasks.reduce import (
    CtxDMTaskParameters,
    DMTaskParameters,
    DMTaskRandomModParameters,
    MultyReduceTasks,
    RomoTaskParameters,
    RomoTaskRandomModParameters,
    GoTaskParameters,
    GoTaskRandomModParameters,
    GoRtTaskParameters,
    GoRtTaskRandomModParameters,
    GoDlTaskParameters,
    GoDlTaskRandomModParameters,
)
import matplotlib.pyplot as plt

# %%
go_task_list_values = np.linspace(0, 1, 8)

batch_size = 1
number_of_tasks = 1
romo_parameters = RomoTaskRandomModParameters(
    romo=RomoTaskParameters(
        delay=0.2,
        positive_shift_delay_time=1.5,
        trial_time=0.2,
        positive_shift_trial_time=0.4,
        answer_time=0.25,
    ),
)
dm_parameters = DMTaskRandomModParameters(
    dm=DMTaskParameters(trial_time=0.3, positive_shift_trial_time=1.5, answer_time=0.25)
)
ctx_parameters = CtxDMTaskParameters(dm=dm_parameters.dm)
go_parameters = GoTaskRandomModParameters(
    go=GoTaskParameters(
        trial_time=0.3,
        positive_shift_trial_time=1.5,
        value=go_task_list_values,
        answer_time=0.25,
    )
)
gort_parameters = GoRtTaskRandomModParameters(
    go_rt=GoRtTaskParameters(
        trial_time=0.3,
        positive_shift_trial_time=1.5,
        answer_time=1.5,
        value=go_task_list_values,
    )
)
godl_parameters = GoDlTaskRandomModParameters(
    go_dl=GoDlTaskParameters(
        go=GoTaskParameters(
            trial_time=0.2,
            positive_shift_trial_time=0.4,
            answer_time=0.25,
            value=go_task_list_values,
        ),
        delay=0.2,
        positive_shift_delay_time=1.5,
    )
)
sigma = 0.5
tasks = [
    "RomoTask1",
    "RomoTask2",
    "DMTask1",
    "DMTask2",
    "CtxDMTask1",
    "CtxDMTask2",
    "GoTask1",
    "GoTask2",
    "GoRtTask1",
    "GoRtTask2",
    "GoDlTask1",
    "GoDlTask2",
]
task_dict = {
    tasks[0]: romo_parameters,
    tasks[1]: romo_parameters,
    tasks[2]: dm_parameters,
    tasks[3]: dm_parameters,
    tasks[4]: ctx_parameters,
    tasks[5]: ctx_parameters,
    tasks[6]: go_parameters,
    tasks[7]: go_parameters,
    tasks[8]: gort_parameters,
    tasks[9]: gort_parameters,
    tasks[10]: godl_parameters,
    tasks[11]: godl_parameters,
}

tasks_sequence = [
    MultyReduceTasks(
        tasks=task_dict,
        batch_size=batch_size,
        delay_between=0,
        enable_fixation_delay=True,
        task_number=i,
    )
    for i in range(len(tasks))
]

# %%
from cgtasknet.net import SNNlifadex
from norse.torch import LIFAdExParameters

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
feature_size, output_size = tasks_sequence[0].feature_and_act_size
hidden_size = 256

neuron_parameters = LIFAdExParameters(
    v_th=torch.as_tensor(0.65),
    tau_ada_inv=0.5,
    alpha=100,
    method="super",
    # rho_reset = torch.as_tensor(5)
)
model = SNNlifadex(
    feature_size,
    hidden_size,
    output_size,
    neuron_parameters=neuron_parameters,
    tau_filter_inv=50,
    save_states=True,
    return_spiking=True,
).to(device)
model.load_state_dict(
    torch.load(
        r"A:\src\multy_task\models\low_freq\bound_and_square_after\weights\weights_100_N_256_1999_"
    )
)
# Out:
# <All keys matched successfully>

# %%
from sklearn.cluster import KMeans

subgroups = EveryTaskSubgroups(model, tasks_sequence)

subgroups.device = device
fixations, answers = [], []
for i in range(100):
    subgroups.run(1)
    fix, ans = subgroups.get_frequencies()
    fixations.append(
        [el.detach().cpu().numpy() if el is not None else None for el in fix]
    )
    answers.append([el.detach().cpu().numpy() for el in ans])
# Out:
# ******************** Start
# Complete task: 0, time: 3.0296655999999977s
# Complete task: 1, time: 1.3969994000000021s
# Complete task: 2, time: 0.8949829000000022s
# Complete task: 3, time: 0.9538547000000008s
# Complete task: 4, time: 0.6600119000000007s
# Complete task: 5, time: 3.6869113999999996s
# Complete task: 6, time: 1.7496385999999973s
# Complete task: 7, time: 7.1316989000000035s
# Complete task: 8, time: 1.8632683999999955s
# Complete task: 9, time: 0.8758554000000061s
# Complete task: 10, time: 1.7177352s
# Complete task: 11, time: 1.409423199999999s
# ******************** Start
# Complete task: 0, time: 1.0183397999999997s
# Complete task: 1, time: 1.3707815999999937s
# Complete task: 2, time: 0.7852931000000041s
# Complete task: 3, time: 0.5917614999999969s
# Complete task: 4, time: 1.2042793999999972s
# Complete task: 5, time: 1.4820095000000038s
# Complete task: 6, time: 2.1117466000000036s
# Complete task: 7, time: 2.8070783000000006s
# Complete task: 8, time: 2.343418800000002s
# Complete task: 9, time: 1.5271708000000075s
# Complete task: 10, time: 1.4539055999999988s
# Complete task: 11, time: 1.7672435000000064s
# ******************** Start
# Complete task: 0, time: 0.7398067999999967s
# Complete task: 1, time: 0.7038004999999998s
# Complete task: 2, time: 1.2878452000000067s
# Complete task: 3, time: 0.762925199999998s
# Complete task: 4, time: 1.2493472999999966s
# Complete task: 5, time: 0.9817438000000038s
# Complete task: 6, time: 2.445128000000011s
# Complete task: 7, time: 2.093906500000003s
# Complete task: 8, time: 1.614871199999996s
# Complete task: 9, time: 1.3708281000000113s
# Complete task: 10, time: 1.3257935000000032s
# Complete task: 11, time: 2.0867031000000082s
# ******************** Start
# Complete task: 0, time: 1.594893600000006s
# Complete task: 1, time: 1.7702638000000093s
# Complete task: 2, time: 1.9550010999999898s
# Complete task: 3, time: 1.141199400000005s
# Complete task: 4, time: 2.029640999999998s
# Complete task: 5, time: 1.9961595000000045s
# Complete task: 6, time: 1.9010365999999976s
# Complete task: 7, time: 2.2280039000000045s
# Complete task: 8, time: 1.4403633000000013s
# Complete task: 9, time: 0.7845776999999998s
# Complete task: 10, time: 5.200281500000003s
# Complete task: 11, time: 1.8308121000000028s
# ******************** Start
# Complete task: 0, time: 1.1674316999999945s
# Complete task: 1, time: 1.5150112999999976s
# Complete task: 2, time: 1.3825736999999947s
# Complete task: 3, time: 0.7910242000000096s
# Complete task: 4, time: 2.0412892000000085s
# Complete task: 5, time: 1.1463388999999893s
# Complete task: 6, time: 2.067908900000006s
# Complete task: 7, time: 2.7619095999999956s
# Complete task: 8, time: 0.5871357999999987s
# Complete task: 9, time: 0.7092926000000119s
# Complete task: 10, time: 5.225340099999997s
# Complete task: 11, time: 2.2165533000000153s
# ******************** Start
# Complete task: 0, time: 1.307895099999996s
# Complete task: 1, time: 1.7252111999999897s
# Complete task: 2, time: 1.2103208000000052s
# Complete task: 3, time: 1.6537748000000079s
# Complete task: 4, time: 2.01702929999999s
# Complete task: 5, time: 1.229709999999983s
# Complete task: 6, time: 2.632700199999988s
# Complete task: 7, time: 2.731286400000016s
# Complete task: 8, time: 0.5221651999999892s
# Complete task: 9, time: 0.8993255000000033s
# Complete task: 10, time: 1.8238753999999915s
# Complete task: 11, time: 1.5542883000000245s
# ******************** Start
# Complete task: 0, time: 0.9540863000000002s
# Complete task: 1, time: 1.712260499999985s
# Complete task: 2, time: 1.037499099999991s
# Complete task: 3, time: 1.564997500000004s
# Complete task: 4, time: 2.314634799999993s
# Complete task: 5, time: 3.0078291000000092s
# Complete task: 6, time: 2.1090157999999803s
# Complete task: 7, time: 2.3692154000000016s
# Complete task: 8, time: 1.6503634999999974s
# Complete task: 9, time: 0.6005269000000055s
# Complete task: 10, time: 2.2491547000000196s
# Complete task: 11, time: 3.5905987000000152s
# ******************** Start
# Complete task: 0, time: 0.7450489000000005s
# Complete task: 1, time: 1.2164774000000023s
# Complete task: 2, time: 1.4273799999999994s
# Complete task: 3, time: 0.9967238000000123s
# Complete task: 4, time: 1.4848743000000013s
# Complete task: 5, time: 1.8806496999999922s
# Complete task: 6, time: 2.0130001999999934s
# Complete task: 7, time: 2.9316358000000093s
# Complete task: 8, time: 3.3473106000000143s
# Complete task: 9, time: 1.3962621000000013s
# Complete task: 10, time: 1.9818640999999957s
# Complete task: 11, time: 4.016879199999977s
# ******************** Start
# Complete task: 0, time: 0.8141931000000113s
# Complete task: 1, time: 0.5873447999999826s
# Complete task: 2, time: 1.283876399999997s
# Complete task: 3, time: 1.3721969000000058s
# Complete task: 4, time: 1.426589899999982s
# Complete task: 5, time: 1.0096417999999971s
# Complete task: 6, time: 1.670017200000018s
# Complete task: 7, time: 2.6702022999999997s
# Complete task: 8, time: 1.3365879999999777s
# Complete task: 9, time: 1.8636242000000038s
# Complete task: 10, time: 3.501349299999987s
# Complete task: 11, time: 3.7033071999999834s
# ******************** Start
# Complete task: 0, time: 0.8275049000000081s
# Complete task: 1, time: 1.5675971999999945s
# Complete task: 2, time: 1.8403818999999828s
# Complete task: 3, time: 0.5668879000000118s
# Complete task: 4, time: 0.7223423999999738s
# Complete task: 5, time: 0.995736700000009s
# Complete task: 6, time: 4.4671156s
# Complete task: 7, time: 2.394638499999985s
# Complete task: 8, time: 0.8419989999999871s
# Complete task: 9, time: 1.1349155999999994s
# Complete task: 10, time: 2.0956917999999973s
# Complete task: 11, time: 1.9419116999999915s
# ******************** Start
# Complete task: 0, time: 0.5769362000000058s
# Complete task: 1, time: 1.1845707999999888s
# Complete task: 2, time: 1.2887344000000098s
# Complete task: 3, time: 0.847598000000005s
# Complete task: 4, time: 0.94515770000001s
# Complete task: 5, time: 1.7879352999999867s
# Complete task: 6, time: 1.6406767000000002s
# Complete task: 7, time: 2.774637399999989s
# Complete task: 8, time: 0.5682199000000026s
# Complete task: 9, time: 0.9020027999999911s
# Complete task: 10, time: 1.4786869000000138s
# Complete task: 11, time: 1.8102698000000146s
# ******************** Start
# Complete task: 0, time: 1.6176676999999984s
# Complete task: 1, time: 0.9545154000000196s
# Complete task: 2, time: 0.7698991999999691s
# Complete task: 3, time: 1.5134338999999954s
# Complete task: 4, time: 2.0446350999999936s
# Complete task: 5, time: 0.7399422999999956s
# Complete task: 6, time: 2.5119917999999757s
# Complete task: 7, time: 3.494162500000016s
# Complete task: 8, time: 1.2420779999999922s
# Complete task: 9, time: 1.0096527000000037s
# Complete task: 10, time: 1.6185396999999853s
# Complete task: 11, time: 1.8238938999999732s
# ******************** Start
# Complete task: 0, time: 0.8106712000000016s
# Complete task: 1, time: 0.7840672000000382s
# Complete task: 2, time: 1.1568902999999864s
# Complete task: 3, time: 0.7806595999999786s
# Complete task: 4, time: 1.385610799999995s
# Complete task: 5, time: 1.4731596999999965s
# Complete task: 6, time: 1.750857499999995s
# Complete task: 7, time: 1.824919800000032s
# Complete task: 8, time: 1.0433084999999664s
# Complete task: 9, time: 0.8146474999999782s
# Complete task: 10, time: 3.7469025999999985s
# Complete task: 11, time: 3.675247899999988s
# ******************** Start
# Complete task: 0, time: 2.4050576000000206s
# Complete task: 1, time: 0.6589053000000149s
# Complete task: 2, time: 0.9723469999999566s
# Complete task: 3, time: 0.4811336999999867s
# Complete task: 4, time: 1.3840401000000497s
# Complete task: 5, time: 2.0853082000000427s
# Complete task: 6, time: 2.093922599999985s
# Complete task: 7, time: 1.5521761999999626s
# Complete task: 8, time: 0.9051591000000485s
# Complete task: 9, time: 0.7391311000000087s
# Complete task: 10, time: 1.6713494999999625s
# Complete task: 11, time: 2.1563931000000025s
# ******************** Start
# Complete task: 0, time: 1.5895691000000056s
# Complete task: 1, time: 0.6529755999999907s
# Complete task: 2, time: 1.494582199999968s
# Complete task: 3, time: 1.2646539999999504s
# Complete task: 4, time: 1.3827483999999686s
# Complete task: 5, time: 2.39802480000003s
# Complete task: 6, time: 1.9758411999999907s
# Complete task: 7, time: 4.778091599999982s
# Complete task: 8, time: 0.8050151999999571s
# Complete task: 9, time: 0.9404588999999532s
# Complete task: 10, time: 2.331768600000032s
# Complete task: 11, time: 1.8100999000000115s
# ******************** Start
# Complete task: 0, time: 1.493991699999981s
# Complete task: 1, time: 1.2105324999999993s
# Complete task: 2, time: 1.0045939000000317s
# Complete task: 3, time: 1.5922873000000095s
# Complete task: 4, time: 1.7879249000000073s
# Complete task: 5, time: 1.6907737999999881s
# Complete task: 6, time: 2.347150299999953s
# Complete task: 7, time: 3.9144977999999924s
# Complete task: 8, time: 1.2007211000000098s
# Complete task: 9, time: 1.1240719999999556s
# Complete task: 10, time: 2.183916399999987s
# Complete task: 11, time: 3.8429133999999863s
# ******************** Start
# Complete task: 0, time: 0.9477512999999931s
# Complete task: 1, time: 1.319486999999981s
# Complete task: 2, time: 1.1426071000000206s
# Complete task: 3, time: 0.5476184999999987s
# Complete task: 4, time: 0.9670973000000345s
# Complete task: 5, time: 3.3686308000000054s
# Complete task: 6, time: 2.2169078000000013s
# Complete task: 7, time: 4.7501603000000046s
# Complete task: 8, time: 0.9481870000000185s
# Complete task: 9, time: 1.8116254000000254s
# Complete task: 10, time: 2.3485172000000034s
# Complete task: 11, time: 2.4354834000000096s
# ******************** Start
# Complete task: 0, time: 0.843618499999991s
# Complete task: 1, time: 1.932066500000019s
# Complete task: 2, time: 1.586734799999988s
# Complete task: 3, time: 0.5109271999999692s
# Complete task: 4, time: 1.0811122000000069s
# Complete task: 5, time: 1.7182591000000116s
# Complete task: 6, time: 3.7771108000000027s
# Complete task: 7, time: 3.958911999999998s
# Complete task: 8, time: 1.1379875000000084s
# Complete task: 9, time: 0.5734961999999655s
# Complete task: 10, time: 1.8830462999999895s
# Complete task: 11, time: 1.5274259999999913s
# ******************** Start
# Complete task: 0, time: 1.4590944000000263s
# Complete task: 1, time: 1.065452100000016s
# Complete task: 2, time: 0.6493638999999689s
# Complete task: 3, time: 1.5017442000000187s
# Complete task: 4, time: 1.8517512999999894s
# Complete task: 5, time: 1.4611454999999864s
# Complete task: 6, time: 2.0333310000000324s
# Complete task: 7, time: 1.563523900000007s
# Complete task: 8, time: 1.1959982999999852s
# Complete task: 9, time: 1.6077314000000342s
# Complete task: 10, time: 2.238271999999995s
# Complete task: 11, time: 1.4228099000000043s
# ******************** Start
# Complete task: 0, time: 0.6491383000000042s
# Complete task: 1, time: 0.55196380000001s
# Complete task: 2, time: 1.227217899999971s
# Complete task: 3, time: 0.968454099999974s
# Complete task: 4, time: 1.9453427999999917s
# Complete task: 5, time: 2.9464492000000178s
# Complete task: 6, time: 5.760313300000007s
# Complete task: 7, time: 1.7662612999999965s
# Complete task: 8, time: 1.321977199999992s
# Complete task: 9, time: 1.5276561000000015s
# Complete task: 10, time: 1.8995219999999904s
# Complete task: 11, time: 1.0570146999999679s
# ******************** Start
# Complete task: 0, time: 1.276059900000007s
# Complete task: 1, time: 1.5784396000000243s
# Complete task: 2, time: 0.9480217000000266s
# Complete task: 3, time: 1.195430799999997s
# Complete task: 4, time: 1.7314342000000238s
# Complete task: 5, time: 1.0961828000000082s
# Complete task: 6, time: 2.6772955999999795s
# Complete task: 7, time: 2.0983233999999698s
# Complete task: 8, time: 0.6812674999999899s
# Complete task: 9, time: 0.4769292999999948s
# Complete task: 10, time: 1.4660249000000363s
# Complete task: 11, time: 1.3255922000000169s
# ******************** Start
# Complete task: 0, time: 1.6743296000000214s
# Complete task: 1, time: 0.6678827000000069s
# Complete task: 2, time: 1.0051412000000255s
# Complete task: 3, time: 0.6618844000000195s
# Complete task: 4, time: 1.8787719999999695s
# Complete task: 5, time: 1.6920496999999841s
# Complete task: 6, time: 2.024634600000013s
# Complete task: 7, time: 1.9204162999999994s
# Complete task: 8, time: 1.5609967000000324s
# Complete task: 9, time: 1.4147145000000023s
# Complete task: 10, time: 2.5814945000000193s
# Complete task: 11, time: 2.1658822999999643s
# ******************** Start
# Complete task: 0, time: 0.6014456999999993s
# Complete task: 1, time: 1.3507503000000156s
# Complete task: 2, time: 0.9490771999999765s
# Complete task: 3, time: 0.8067179999999894s
# Complete task: 4, time: 2.218238700000029s
# Complete task: 5, time: 2.3355408000000466s
# Complete task: 6, time: 2.3464987000000406s
# Complete task: 7, time: 3.6636386999999786s
# Complete task: 8, time: 1.4309736999999814s
# Complete task: 9, time: 1.6136227999999733s
# Complete task: 10, time: 2.0479574999999954s
# Complete task: 11, time: 1.8030982999999878s
# ******************** Start
# Complete task: 0, time: 1.088305900000023s
# Complete task: 1, time: 0.6142500000000268s
# Complete task: 2, time: 1.2062677999999778s
# Complete task: 3, time: 1.5309045999999853s
# Complete task: 4, time: 1.776862000000051s
# Complete task: 5, time: 0.8171431000000098s
# Complete task: 6, time: 1.893466999999987s
# Complete task: 7, time: 2.1400831000000267s
# Complete task: 8, time: 0.7722322999999847s
# Complete task: 9, time: 1.1938289000000282s
# Complete task: 10, time: 1.4128173000000288s
# Complete task: 11, time: 2.0446484000000282s
# ******************** Start
# Complete task: 0, time: 0.46588939999998047s
# Complete task: 1, time: 1.1465281000000118s
# Complete task: 2, time: 0.5093045999999504s
# Complete task: 3, time: 1.1154131000000689s
# Complete task: 4, time: 1.4075800000000527s
# Complete task: 5, time: 1.5023073999999497s
# Complete task: 6, time: 2.6781425000000354s
# Complete task: 7, time: 2.232096100000035s
# Complete task: 8, time: 1.5121543999999858s
# Complete task: 9, time: 1.9449100000000499s
# Complete task: 10, time: 1.6755904999999984s
# Complete task: 11, time: 1.1394467000000077s
# ******************** Start
# Complete task: 0, time: 1.1007495000000063s
# Complete task: 1, time: 1.0182297000000062s
# Complete task: 2, time: 2.530655599999932s
# Complete task: 3, time: 0.4776975999999422s
# Complete task: 4, time: 2.618658400000072s
# Complete task: 5, time: 1.1341069000000061s
# Complete task: 6, time: 2.392245799999955s
# Complete task: 7, time: 2.1179488999999876s
# Complete task: 8, time: 1.3815643000000364s
# Complete task: 9, time: 1.2962373000000298s
# Complete task: 10, time: 1.06980800000008s
# Complete task: 11, time: 1.6267882000000782s
# ******************** Start
# Complete task: 0, time: 1.4188580000000002s
# Complete task: 1, time: 1.1173282000000881s
# Complete task: 2, time: 1.134688399999959s
# Complete task: 3, time: 0.7578644000000168s
# Complete task: 4, time: 1.8359603000000106s
# Complete task: 5, time: 3.461501500000054s
# Complete task: 6, time: 2.1953035999999884s
# Complete task: 7, time: 2.1493868999999677s
# Complete task: 8, time: 0.6589735999999675s
# Complete task: 9, time: 0.9768093999999792s
# Complete task: 10, time: 1.0100206999999273s
# Complete task: 11, time: 1.6946386000000757s
# ******************** Start
# Complete task: 0, time: 0.8982341000000815s
# Complete task: 1, time: 1.1795918999999913s
# Complete task: 2, time: 0.7170556999999462s
# Complete task: 3, time: 1.4796458999999231s
# Complete task: 4, time: 1.5434324999999944s
# Complete task: 5, time: 1.04183050000006s
# Complete task: 6, time: 2.5023577999999134s
# Complete task: 7, time: 2.2239198000000897s
# Complete task: 8, time: 1.5510989000000563s
# Complete task: 9, time: 1.38467849999995s
# Complete task: 10, time: 0.8630039999999326s
# Complete task: 11, time: 5.046573599999988s
# ******************** Start
# Complete task: 0, time: 1.1406663999999864s
# Complete task: 1, time: 0.5147807000000739s
# Complete task: 2, time: 0.8807174000000941s
# Complete task: 3, time: 0.5505046000000675s
# Complete task: 4, time: 1.3171254999999746s
# Complete task: 5, time: 1.7927200000000312s
# Complete task: 6, time: 2.3718149999999696s
# Complete task: 7, time: 2.0225633999999673s
# Complete task: 8, time: 1.5029459999999517s
# Complete task: 9, time: 0.8704456000000391s
# Complete task: 10, time: 1.4481892000000016s
# Complete task: 11, time: 1.6973656999999776s
# ******************** Start
# Complete task: 0, time: 2.1632058000000143s
# Complete task: 1, time: 0.7675348000000213s
# Complete task: 2, time: 1.2540132000000312s
# Complete task: 3, time: 1.6070346999999856s
# Complete task: 4, time: 0.6642024999999876s
# Complete task: 5, time: 2.6152351000000635s
# Complete task: 6, time: 2.51357239999993s
# Complete task: 7, time: 1.892986800000017s
# Complete task: 8, time: 0.8116011000000753s
# Complete task: 9, time: 0.8672098000000688s
# Complete task: 10, time: 2.0372519999999668s
# Complete task: 11, time: 2.2537393000000066s
# ******************** Start
# Complete task: 0, time: 1.7956887999999935s
# Complete task: 1, time: 0.6417132000000265s
# Complete task: 2, time: 0.7155503999999837s
# Complete task: 3, time: 0.6347831000000497s
# Complete task: 4, time: 1.6533307000000832s
# Complete task: 5, time: 1.2619017000000667s
# Complete task: 6, time: 1.6617492000000311s
# Complete task: 7, time: 4.121302300000025s
# Complete task: 8, time: 1.02831070000002s
# Complete task: 9, time: 0.8817124999999351s
# Complete task: 10, time: 1.7147140999999237s
# Complete task: 11, time: 1.4615350000000262s
# ******************** Start
# Complete task: 0, time: 1.1995094000000108s
# Complete task: 1, time: 0.9007838999999649s
# Complete task: 2, time: 1.1596923999999262s
# Complete task: 3, time: 1.448846499999945s
# Complete task: 4, time: 2.317276700000093s
# Complete task: 5, time: 3.2774045999999544s
# Complete task: 6, time: 5.9628218999999945s
# Complete task: 7, time: 2.8499976999999035s
# Complete task: 8, time: 1.0261925999999448s
# Complete task: 9, time: 0.933151799999905s
# Complete task: 10, time: 1.602428600000053s
# Complete task: 11, time: 1.8026723000000402s
# ******************** Start
# Complete task: 0, time: 0.6164251999999806s
# Complete task: 1, time: 1.334856699999932s
# Complete task: 2, time: 1.4182439000001068s
# Complete task: 3, time: 1.2005145999999058s
# Complete task: 4, time: 1.8866648000000623s
# Complete task: 5, time: 1.5017877999999882s
# Complete task: 6, time: 1.8278315999999677s
# Complete task: 7, time: 2.5892191000000366s
# Complete task: 8, time: 1.548268099999973s
# Complete task: 9, time: 1.6880684999999858s
# Complete task: 10, time: 2.0667779999999993s
# Complete task: 11, time: 1.2571929000000637s
# ******************** Start
# Complete task: 0, time: 1.558998200000019s
# Complete task: 1, time: 1.1433468999999832s
# Complete task: 2, time: 0.8747619999999188s
# Complete task: 3, time: 1.6853258999999525s
# Complete task: 4, time: 1.4239532000000281s
# Complete task: 5, time: 1.4389472999999953s
# Complete task: 6, time: 2.5595325000000457s
# Complete task: 7, time: 1.8485780000000887s
# Complete task: 8, time: 1.5803902000000107s
# Complete task: 9, time: 0.5762740999999778s
# Complete task: 10, time: 1.6701381999999967s
# Complete task: 11, time: 2.964319400000022s
# ******************** Start
# Complete task: 0, time: 1.1760127000000011s
# Complete task: 1, time: 1.114563799999928s
# Complete task: 2, time: 2.145869100000027s
# Complete task: 3, time: 1.3084761999999728s
# Complete task: 4, time: 1.3525838000000476s
# Complete task: 5, time: 1.3629267999999684s
# Complete task: 6, time: 1.6371791999999914s
# Complete task: 7, time: 2.704742200000055s
# Complete task: 8, time: 1.7078030999999783s
# Complete task: 9, time: 1.3128231000000596s
# Complete task: 10, time: 2.159409299999993s
# Complete task: 11, time: 1.2751461999999947s
# ******************** Start
# Complete task: 0, time: 0.68974460000004s
# Complete task: 1, time: 0.5830527000000529s
# Complete task: 2, time: 0.9760604000000512s
# Complete task: 3, time: 0.7019138000000567s
# Complete task: 4, time: 0.8767519000000448s
# Complete task: 5, time: 2.882504899999958s
# Complete task: 6, time: 3.604423699999984s
# Complete task: 7, time: 1.8119285999999875s
# Complete task: 8, time: 0.5348458999999366s
# Complete task: 9, time: 0.7418586999999661s
# Complete task: 10, time: 1.8190521000000217s
# Complete task: 11, time: 1.4493962999999894s
# ******************** Start
# Complete task: 0, time: 1.4535882000000129s
# Complete task: 1, time: 1.6827150000000302s
# Complete task: 2, time: 1.7915309999999636s
# Complete task: 3, time: 1.8411551000000372s
# Complete task: 4, time: 1.9034070999999813s
# Complete task: 5, time: 1.3504608000000644s
# Complete task: 6, time: 2.2894182999999657s
# Complete task: 7, time: 1.8356721000000107s
# Complete task: 8, time: 0.5807172999999466s
# Complete task: 9, time: 1.5788124000000607s
# Complete task: 10, time: 2.2912809999999126s
# Complete task: 11, time: 1.4186542999999574s
# ******************** Start
# Complete task: 0, time: 1.1637900999999147s
# Complete task: 1, time: 1.420307600000001s
# Complete task: 2, time: 1.491109100000017s
# Complete task: 3, time: 1.7164378999999599s
# Complete task: 4, time: 1.1378270000000157s
# Complete task: 5, time: 1.2141077999999652s
# Complete task: 6, time: 1.5986424999999826s
# Complete task: 7, time: 2.398529300000064s
# Complete task: 8, time: 2.5478786999999556s
# Complete task: 9, time: 0.8964458000000377s
# Complete task: 10, time: 1.680464200000074s
# Complete task: 11, time: 1.5692477000000054s
# ******************** Start
# Complete task: 0, time: 1.637223400000039s
# Complete task: 1, time: 0.6230454999999893s
# Complete task: 2, time: 0.5362357000000202s
# Complete task: 3, time: 1.5238068999999541s
# Complete task: 4, time: 0.7255298999999695s
# Complete task: 5, time: 1.5686169000000518s
# Complete task: 6, time: 2.6399823000000424s
# Complete task: 7, time: 2.0965956000000006s
# Complete task: 8, time: 0.641169600000012s
# Complete task: 9, time: 1.222784200000092s
# Complete task: 10, time: 1.8010708000000477s
# Complete task: 11, time: 1.8629114999999956s
# ******************** Start
# Complete task: 0, time: 0.6633209000000306s
# Complete task: 1, time: 1.4132309999999961s
# Complete task: 2, time: 0.9361306999999215s
# Complete task: 3, time: 0.4551821000000018s
# Complete task: 4, time: 1.1647166000000198s
# Complete task: 5, time: 0.645620200000053s
# Complete task: 6, time: 4.936639799999966s
# Complete task: 7, time: 2.01665950000006s
# Complete task: 8, time: 0.9648378999999068s
# Complete task: 9, time: 1.2685722999999598s
# Complete task: 10, time: 2.221747800000003s
# Complete task: 11, time: 1.3511660000000347s
# ******************** Start
# Complete task: 0, time: 1.3425475000000233s
# Complete task: 1, time: 1.0934914999999137s
# Complete task: 2, time: 1.0767663000000312s
# Complete task: 3, time: 1.509686600000009s
# Complete task: 4, time: 1.489298299999973s
# Complete task: 5, time: 0.8180152999999564s
# Complete task: 6, time: 2.2578234000000066s
# Complete task: 7, time: 2.3898516000000427s
# Complete task: 8, time: 0.624214699999925s
# Complete task: 9, time: 0.6974845999999388s
# Complete task: 10, time: 1.3989878999999519s
# Complete task: 11, time: 2.6049979000000576s
# ******************** Start
# Complete task: 0, time: 1.6130030000000488s
# Complete task: 1, time: 1.0320595000000594s
# Complete task: 2, time: 1.01667580000003s
# Complete task: 3, time: 1.7026476999999431s
# Complete task: 4, time: 0.9828715999999531s
# Complete task: 5, time: 1.6315643000000364s
# Complete task: 6, time: 2.014077499999985s
# Complete task: 7, time: 1.9430161999999882s
# Complete task: 8, time: 0.645868099999916s
# Complete task: 9, time: 1.4259375999999975s
# Complete task: 10, time: 2.278164800000013s
# Complete task: 11, time: 1.5514402999999675s
# ******************** Start
# Complete task: 0, time: 0.6403746000000865s
# Complete task: 1, time: 2.0200618999999733s
# Complete task: 2, time: 1.8476157999999714s
# Complete task: 3, time: 1.0150683999999046s
# Complete task: 4, time: 1.9464097999999694s
# Complete task: 5, time: 1.619952200000057s
# Complete task: 6, time: 1.8449964999999793s
# Complete task: 7, time: 5.208356299999991s
# Complete task: 8, time: 1.7356415000000425s
# Complete task: 9, time: 2.0692602999999963s
# Complete task: 10, time: 2.4473323000000846s
# Complete task: 11, time: 1.984041599999955s
# ******************** Start
# Complete task: 0, time: 0.6933685000000196s
# Complete task: 1, time: 3.183829199999991s
# Complete task: 2, time: 0.8049205999999458s
# Complete task: 3, time: 1.2664687000000185s
# Complete task: 4, time: 1.8746819999998934s
# Complete task: 5, time: 1.2871383000000378s
# Complete task: 6, time: 2.3634832999999844s
# Complete task: 7, time: 4.990671499999962s
# Complete task: 8, time: 0.9637615000000324s
# Complete task: 9, time: 1.562848600000052s
# Complete task: 10, time: 1.553622599999926s
# Complete task: 11, time: 1.2799630000000661s
# ******************** Start
# Complete task: 0, time: 1.3937658999999485s
# Complete task: 1, time: 1.1088426000000027s
# Complete task: 2, time: 1.3648529000000735s
# Complete task: 3, time: 0.6314939999999751s
# Complete task: 4, time: 1.7907615000000305s
# Complete task: 5, time: 1.8713836999999103s
# Complete task: 6, time: 2.6846782000000076s
# Complete task: 7, time: 1.7102452999999969s
# Complete task: 8, time: 2.1277966999999762s
# Complete task: 9, time: 1.0445276000000376s
# Complete task: 10, time: 3.627810499999896s
# Complete task: 11, time: 2.4959479999999985s
# ******************** Start
# Complete task: 0, time: 1.7681309000000738s
# Complete task: 1, time: 1.3719551000000365s
# Complete task: 2, time: 0.937986799999976s
# Complete task: 3, time: 1.129854499999965s
# Complete task: 4, time: 0.8869913999999426s
# Complete task: 5, time: 2.6171315000000277s
# Complete task: 6, time: 2.023336699999959s
# Complete task: 7, time: 3.3834405999999717s
# Complete task: 8, time: 0.9261357999999973s
# Complete task: 9, time: 1.2412702000000309s
# Complete task: 10, time: 2.3258813999999575s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <module>
#       6 fixations, answers = [], []
#       7 for i in range(100):
# ----> 8     subgroups.run(1)
#       9     fix, ans = subgroups.get_frequencies()
#      10     fixations.append([el.detach().cpu().numpy() if el is not None else None for el in fix])
#
# Input In [1], in EveryTaskSubgroups.run(self, number_of_trials, dt)
#      29     status = False
#      30     while not status:
# ---> 31         inputs, t_outputs, s, out = self._run_trial(current_task)
#      32         status = self._subgroups_finder[-1].compute_average_freq(
#      33             [s.to(torch.device("cpu"))],
#      34             [inputs[:, 0, 0].to(torch.device("cpu"))],
#      35             [out.to(torch.device("cpu"))],
#      36             [t_outputs.to(torch.device("cpu"))],
#      37         )
#      38 print(
#      39     f"Complete task: {current_task.task_number}, time: {time.perf_counter() - t0}s"
#      40 )
#
# Input In [1], in EveryTaskSubgroups._run_trial(self, task)
#      44 inputs = torch.from_numpy(inputs).type(torch.float).to(self.device)
#      45 t_outputs = torch.from_numpy(t_outputs).type(torch.float).to(self.device)
# ---> 46 out, _, s = self._model(inputs)
#      47 s = torch.stack(s).detach()
#      48 s = s.reshape((s.shape[0], s.shape[2]))
#
# File a:\src\multy_task\env\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File a:\src\multy_task\env\lib\site-packages\cgtasknet-0.0.1-py3.8.egg\cgtasknet\net\lifadex.py:48, in SNNlifadex.forward(self, x, state, additional_current)
#      39 def forward(
#      40     self,
#      41     x: torch.tensor,
#    (...)
#      46     Tuple[torch.tensor, torch.tensor],
#      47 ]:
# ---> 48     outputs, states = save_states(
#      49         x, self.save_states, self.alif, state, additional_current
#      50     )
#      52     outputs = self.exp_f(outputs)
#      54     if self.return_spiking and self.save_states:
#
# File a:\src\multy_task\env\lib\site-packages\cgtasknet-0.0.1-py3.8.egg\cgtasknet\net\save_states.py:25, in save_states(x, save_states, layer, state, additional_current)
#      19 if additional_current is not None:
#      20     s = (
#      21         LIFAdExState(s.z, s.v, s.i + additional_current[ts], s.a)
#      22         if s is not None
#      23         else None
#      24     )
# ---> 25 out, s = layer(x[ts : ts + 1, :, :], state=s)
#      26 outputs.append(out)
#      27 if save_states:
#
# File a:\src\multy_task\env\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File a:\src\multy_task\env\lib\site-packages\norse-0.0.7.post1-py3.8-win-amd64.egg\norse\torch\module\snn.py:317, in SNNRecurrent.forward(self, input_tensor, state)
#     310 activation = (
#     311     self.activation_sparse
#     312     if self.activation_sparse is not None and input_tensor.is_sparse
#     313     else self.activation
#     314 )
#     316 for ts in range(T):
# --> 317     out, state = activation(
#     318         input_tensor[ts],
#     319         state,
#     320         self.input_weights,
#     321         self.recurrent_weights,
#     322         self.p,
#     323         self.dt,
#     324     )
#     325     outputs.append(out)
#     327 return torch.stack(outputs), state
#
# File a:\src\multy_task\env\lib\site-packages\norse-0.0.7.post1-py3.8-win-amd64.egg\norse\torch\functional\lif_adex.py:131, in lif_adex_step(input_tensor, state, input_weights, recurrent_weights, p, dt)
#     128 i_decayed = state.i + di
#     130 # Compute adaptation update
# --> 131 da = dt * p.tau_ada_inv * (p.adaptation_current * (state.v - p.v_leak) - state.a)
#     132 a_decayed = state.a + da
#     134 # compute new spikes
#
# KeyboardInterrupt:

# %%
answers_np = np.array(answers).T
answers_np = answers_np.reshape(
    answers_np.shape[-1] * answers_np.shape[-2], answers_np.shape[0]
).T
# indexes = np.where(answers_np.mean(axis=1) > 25)[0]
answers_np = np.concatenate(answers).T + 1
# answers_np = answers_np[indexes, :]
answers_np = (answers_np.T / np.sum(answers_np, axis=1)).T
print(answers_np.shape)
# Out:
# (256, 540)

# %%
print(answers_np.shape)
# Out:
# (256, 540)

# %%
X = np.concatenate(fixations, axis=0).T

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
sse = []
for k in range(1, 15):
    kmeans = KMeans(k, algorithm="full", n_init=20, random_state=0)
    kmeans.fit_predict(X)
    sse.append(kmeans.inertia_)
plt.plot(sse, ".")
plt.show()
plt.close()
n_clusters = 3
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
% matplotlib inline
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()
# Out:
# UsageError: Line magic function `%` not found.

# %%
X = np.concatenate(answers, axis=0).T

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
sse = []
for k in range(1, 15):
    kmeans = KMeans(k, algorithm="full", n_init=20, random_state=0)
    kmeans.fit_predict(X)
    sse.append(kmeans.inertia_)
plt.plot(sse, ".")
plt.show()
plt.close()
n_clusters = 2
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
% matplotlib inline
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()
# Out:
# UsageError: Line magic function `%` not found.

# %%
X = np.concatenate(answers + fixations, axis=0).T / 2

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
sse = []
for k in range(1, 15):
    kmeans = KMeans(k, algorithm="full", n_init=20, random_state=0)
    kmeans.fit_predict(X)
    sse.append(kmeans.inertia_)
plt.plot(sse, ".")
plt.show()
plt.close()
n_clusters = 2
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
% matplotlib inline
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
np_variance = np.zeros((np_answers.shape[1], np_answers.shape[2]))
for i in range(np_answers.shape[-1]):
    np_variance[:, i] = np.sum(np_answers[:, :, i], axis=0) / 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [259], in <module>
# ----> 1 np_variance = np.zeros((np_answers.shape[1], np_answers.shape[2]))
#       2 for i in range(np_answers.shape[-1]):
#       3     np_variance[:, i] = np.sum(np_answers[:, :, i], axis=0) / 100
#
# NameError: name 'np_answers' is not defined

# %%
np_variance.shape

# %%
plt.imshow(np_variance / np_variance.max(), aspect="auto", cmap="jet", origin="lower")
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [260], in <module>
# ----> 1 plt.imshow(np_variance / np_variance.max(), aspect='auto', cmap='jet', origin='lower')
#       2 plt.colorbar()
#
# NameError: name 'np_variance' is not defined

# %%
from scipy.cluster import hierarchy
from scipy.spatial.distance import pdist

distance_mat = pdist(
    X
)  # pdist посчитает нам верхний треугольник матрицы попарных расстояний

Z = hierarchy.linkage(
    distance_mat, "single"
)  # linkage — реализация агломеративного алгоритма
plt.figure(figsize=(10, 5))
dn = hierarchy.dendrogram(Z, color_threshold=000)
plt.show()
plt.close()

# %%
X = np.concatenate(answers, axis=0).T
X = X[np.where(X.sum(axis=1) > 950)[0], :]
X.shape
# Out:
# (204, 1200)

# %%
X = np.concatenate(answers, axis=0).T

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
sse = []
for k in range(1, 15):
    kmeans = KMeans(k, algorithm="full", n_init=20, random_state=0)
    kmeans.fit_predict(X)
    sse.append(kmeans.inertia_)
plt.plot(sse, ".")
plt.show()
plt.close()
n_clusters = 3
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
% matplotlib inline
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
X = np.concatenate(answers, axis=0).T + np.concatenate(fixations, axis=0).T
X /= 2

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
n_clusters = 20
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.
# 00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
answers_np = np.array(answers) + np.array(fixations)
answers_np /= 2
tv = [answers_np[:, i, :].sum(axis=0) for i in range(answers_np.shape[1])]
tv = np.array(tv)
# tv = tv[np.where(tv.sum(axis=1) > 0)[0], :]
tv /= tv.max()
tv.shape
# Out:
# (12, 256)

# %%
from cgtasknet.instruments.instrument_subgroups import sort_elemnts_by_another
from matplotlib import cm

sort_indexes = [*range(hidden_size)]
sort_indexes = sort_elemnts_by_another(tv[1], sort_indexes)
tv_sort = np.zeros_like(tv)
clusters = []
for i in range(n_clusters):
    clusters.extend(
        sort_elemnts_by_another(
            np.mean(tv[:, [*np.where(y_km == i)[0]]], axis=0), [*np.where(y_km == i)[0]]
        )
    )
cluster_sizes = []
for i in range(n_clusters):
    cluster_i = [*np.where(y_km == i)[0]]
    cluster_sizes.append(len(cluster_i))
for i in range(n_clusters):
    clusters.extend([*np.where(y_km == i)[0]])
clusters = clusters[::]
for task in range(len(tv)):
    for i in range(hidden_size):
        tv_sort[task, i] = tv[task, clusters[i]]
plt.imshow(
    tv_sort, aspect="auto", origin="lower", cmap="inferno_r", interpolation="nearest"
)
plt.yticks(np.arange(0, len(tasks)), sorted(tasks), rotation=0)
cluster_size = 0
# colors = ["#EF3B3B", "#233DFB", "#49FF00", "#F333FF", "#BF035B", "#23305F"]
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
for i in range(0, len(cluster_sizes)):
    plt.plot(
        [cluster_size, cluster_size + cluster_sizes[i]],
        [-0.4, -0.4],
        label=f"Cluster # {i + 1}",
        c=colors[i],
        linewidth=2,
    )
    # plt.plot([cluster_size ] * 2, [-1, len(tasks_couples)], c='black', linestyle='--', linewidth=.5)
    cluster_size += cluster_sizes[i]
# plt.legend()
plt.xlim(0, 256)
plt.colorbar()
plt.tight_layout()
plt.savefig("Clusters.png", dpi=1500)
plt.show()
plt.close()

# %%
plt.imshow(
    tv_sort, aspect="auto", origin="lower", cmap="rainbow", interpolation="nearest"
)
plt.yticks(np.arange(0, len(tasks)), sorted(tasks), rotation=0)
# plt.xlim(0, 100)
plt.colorbar()
plt.show()
plt.close()

# %%
clusters = X = np.concatenate(fixations, axis=0).T

# X = X[np.where(X.sum(axis=1) > 0)[0], :]
X = (X.T / X.max()).T
n_clusters = 4
km = KMeans(n_clusters, algorithm="full", n_init=20, random_state=0)
y_km = km.fit_predict(X)
% matplotlib inline
for i in range(n_clusters):
    plt.scatter(
        X[y_km == i, 0],
        X[y_km == i, 1],
        s=50,
        marker="s",
        edgecolor="black",
        label=f"cluster {i}",
        alpha=0.8,
    )
# plt.xlim([0, 0.00005])
# plot the centroids
plt.scatter(
    km.cluster_centers_[:, 0],
    km.cluster_centers_[:, 1],
    s=350,
    marker="*",
    c="green",
    edgecolor="black",
    label="centroids",
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()
answers_np = np.array(answers)
tv = [answers_np[:, i, :].sum(axis=0) for i in range(answers_np.shape[1])]
tv = np.array(tv)
# tv = tv[np.where(tv.sum(axis=1) > 0)[0], :]
tv /= tv.max()
tv.shape
from cgtasknet.instruments.instrument_subgroups import sort_elemnts_by_another

sort_indexes = [*range(hidden_size)]
sort_indexes = sort_elemnts_by_another(tv[1], sort_indexes)
tv_sort = np.zeros_like(tv)
clusters = []
for i in range(n_clusters):
    clusters.extend([*np.where(y_km == i)[0]])
clusters = clusters[::-1]
for task in range(len(tv)):
    for i in range(hidden_size):
        tv_sort[task, i] = tv[task, clusters[i]]
plt.imshow(
    tv_sort, aspect="auto", origin="lower", cmap="rainbow", interpolation="nearest"
)
plt.yticks(np.arange(0, len(tasks)), sorted(tasks), rotation=0)
plt.xlim(0, 50)
plt.colorbar()
plt.show()
plt.close()
plt.imshow(
    tv_sort, aspect="auto", origin="lower", cmap="rainbow", interpolation="nearest"
)
plt.yticks(np.arange(0, len(tasks)), sorted(tasks), rotation=0)
# plt.xlim(0, 100)
plt.colorbar()
plt.show()
plt.close()
# Out:
# UsageError: Line magic function `%` not found.

# %%
fixations[9][2]
